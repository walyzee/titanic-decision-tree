# %%
from google.colab import files
import numpy as np
import pandas as pd
import pandas.util.testing as tm
import matplotlib.pyplot as plt
import seaborn as sns
import graphviz
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn import metrics
from sklearn.metrics import classification_report
from sklearn.datasets import make_classification
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import roc_curve
from sklearn.metrics import roc_auc_score
from sklearn import tree   
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score
from sklearn.ensemble import RandomForestClassifier

# %%
df=pd.read_csv('titanic.csv')
df.head()
# Out:
#    pclass  survived  ...   body                        home.dest
# 0     1.0       1.0  ...    NaN                     St Louis, MO
# 1     1.0       1.0  ...    NaN  Montreal, PQ / Chesterville, ON
# 2     1.0       0.0  ...    NaN  Montreal, PQ / Chesterville, ON
# 3     1.0       0.0  ...  135.0  Montreal, PQ / Chesterville, ON
# 4     1.0       0.0  ...    NaN  Montreal, PQ / Chesterville, ON
#
# [5 rows x 14 columns]

# %%
df.tail()
# Out:
#       pclass  survived                       name  ... boat   body  home.dest
# 1305     3.0       0.0      Zabour, Miss. Thamine  ...  NaN    NaN        NaN
# 1306     3.0       0.0  Zakarian, Mr. Mapriededer  ...  NaN  304.0        NaN
# 1307     3.0       0.0        Zakarian, Mr. Ortin  ...  NaN    NaN        NaN
# 1308     3.0       0.0         Zimmerman, Mr. Leo  ...  NaN    NaN        NaN
# 1309     NaN       NaN                        NaN  ...  NaN    NaN        NaN
#
# [5 rows x 14 columns]

# %%
df.describe()
# Out:
#             pclass     survived  ...         fare        body
# count  1309.000000  1309.000000  ...  1308.000000  121.000000
# mean      2.294882     0.381971  ...    33.295479  160.809917
# std       0.837836     0.486055  ...    51.758668   97.696922
# min       1.000000     0.000000  ...     0.000000    1.000000
# 25%       2.000000     0.000000  ...     7.895800   72.000000
# 50%       3.000000     0.000000  ...    14.454200  155.000000
# 75%       3.000000     1.000000  ...    31.275000  256.000000
# max       3.000000     1.000000  ...   512.329200  328.000000
#
# [8 rows x 7 columns]

# %%
df.isnull().sum()
# Out:
# pclass          1
# survived        1
# name            1
# sex             1
# age           264
# sibsp           1
# parch           1
# ticket          1
# fare            2
# cabin        1015
# embarked        3
# boat          824
# body         1189
# home.dest     565
# dtype: int64

# %%
df.dropna(axis=0, how='all', thresh=None, inplace=True)

# %%
df.drop(['body','boat','home.dest','cabin'],'columns',inplace=True)

# %%
df.isnull().sum()
# Out:
# pclass        0
# survived      0
# name          0
# sex           0
# age         263
# sibsp         0
# parch         0
# ticket        0
# fare          1
# embarked      2
# dtype: int64

# %%
df['age'].fillna(df['age'].mean(),inplace=True)
df['age']=df['age'].apply(np.ceil)
df['age']=df['age'].apply(np.int)

# %%
df['pclass'].fillna(df['pclass'].mode()[0],inplace=True)
df['pclass']=df['pclass'].apply(np.int)

# %%
df['embarked'].fillna(df['embarked'].mode()[0],inplace=True)

# %%
df['fare'].fillna(df['fare'].mean(),inplace=True)

# %%
df['sibsp']=df['sibsp'].apply(np.int)

# %%
df['parch']=df['parch'].apply(np.int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1309 entries, 0 to 1308
# Data columns (total 10 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   pclass    1309 non-null   int64
#  1   survived  1309 non-null   float64
#  2   name      1309 non-null   object
#  3   sex       1309 non-null   object
#  4   age       1309 non-null   int64
#  5   sibsp     1309 non-null   int64
#  6   parch     1309 non-null   int64
#  7   ticket    1309 non-null   object
#  8   fare      1309 non-null   float64
#  9   embarked  1309 non-null   object
# dtypes: float64(2), int64(4), object(4)
# memory usage: 112.5+ KB

# %%
grid = sns.FacetGrid(df,col='survived', 
    row='sex', height=2.2, aspect=1.6)
grid.map(plt.hist,'age', bins=20)
grid.add_legend()

# %%
grid=sns.FacetGrid(df,row ='sex' , col = 'survived' , height =2.2 ,  aspect= 1.6)
grid.map(sns.barplot, 'pclass' ,'age', alpha = .5, ci = None)
grid.add_legend()
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/axisgrid.py:723: UserWarning: Using the barplot function without specifying `order` is likely to produce an incorrect plot.
#   warnings.warn(warning)

# %%
def plot_correlation_map( df ):
    corr = df.corr()
    s , ax = plt.subplots( figsize =( 12 , 10 ) )
    cmap = sns.diverging_palette( 220 , 10 , as_cmap = True )
    s = sns.heatmap(
        corr, 
        cmap = cmap,
        square=True, 
        cbar_kws={ 'shrink' : .9 }, 
        ax=ax, 
        annot = True, 
        annot_kws = { 'fontsize' : 12 }
        )

# %%
plot_correlation_map( df )

# %%
title=[]
df1=''
for data in df['name']:
    df1=data.split(',')
    df1=df1[1].split('.')
    title.append(str(df1[0]))
df['title']=title 
df.head()
# Out:
#    pclass  survived  ... embarked    title
# 0       1       1.0  ...        S     Miss
# 1       1       1.0  ...        S   Master
# 2       1       0.0  ...        S     Miss
# 3       1       0.0  ...        S       Mr
# 4       1       0.0  ...        S      Mrs
#
# [5 rows x 11 columns]

# %%
Title_Dictionary = {
                    "Capt":       "Officer",
                    "Col":        "Officer",
                    "Major":      "Officer",
                      "Dr":         "Officer",
                    "Rev":        "Officer",
                    "Jonkheer":   "Royalty",
                    "Don":        "Royalty",
                    "Sir" :       "Royalty",
                   "Lady" :      "Royalty",
                  "the Countess": "Royalty",
                    "Dona":       "Royalty",
                    "Mme":        "Miss",
                    "Mlle":       "Miss",
                    "Miss" :      "Miss",
                    "Ms":         "Mrs",
                    "Mr" :        "Mrs",
                    "Mrs" :       "Mrs",
                    "Master" :    "Master",
                    }

# %%
df['title'].replace(Title_Dictionary, inplace=True)
df.head()
# Out:
#    pclass  survived  ... embarked    title
# 0       1       1.0  ...        S     Miss
# 1       1       1.0  ...        S   Master
# 2       1       0.0  ...        S     Miss
# 3       1       0.0  ...        S       Mr
# 4       1       0.0  ...        S      Mrs
#
# [5 rows x 11 columns]

# %%
df['title'].value_counts()
# Out:
#  Mr              757
#  Miss            260
#  Mrs             197
#  Master           61
#  Dr                8
#  Rev               8
#  Col               4
#  Major             2
#  Ms                2
#  Mlle              2
#  Mme               1
#  Jonkheer          1
#  Dona              1
#  Lady              1
#  Don               1
#  Sir               1
#  Capt              1
#  the Countess      1
# Name: title, dtype: int64

# %%
df['familysize'] = df['sibsp'] + df['parch']
df.head()
# Out:
#    pclass  survived  ...    title familysize
# 0       1       1.0  ...     Miss          0
# 1       1       1.0  ...   Master          3
# 2       1       0.0  ...     Miss          3
# 3       1       0.0  ...       Mr          3
# 4       1       0.0  ...      Mrs          3
#
# [5 rows x 12 columns]

# %% [markdown]
# # Logistic regression

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1309 entries, 0 to 1308
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   pclass      1309 non-null   int64
#  1   survived    1309 non-null   float64
#  2   name        1309 non-null   object
#  3   sex         1309 non-null   object
#  4   age         1309 non-null   int64
#  5   sibsp       1309 non-null   int64
#  6   parch       1309 non-null   int64
#  7   ticket      1309 non-null   object
#  8   fare        1309 non-null   float64
#  9   embarked    1309 non-null   object
#  10  title       1309 non-null   object
#  11  familysize  1309 non-null   int64
# dtypes: float64(2), int64(5), object(5)
# memory usage: 132.9+ KB

# %%
encoder = LabelEncoder()
df['name']=encoder.fit_transform(df['name'])
df.head()
# Out:
#    pclass  survived  name     sex  ...      fare  embarked    title familysize
# 0       1       1.0    21  female  ...  211.3375         S     Miss          0
# 1       1       1.0    23    male  ...  151.5500         S   Master          3
# 2       1       0.0    24  female  ...  151.5500         S     Miss          3
# 3       1       0.0    25    male  ...  151.5500         S       Mr          3
# 4       1       0.0    26  female  ...  151.5500         S      Mrs          3
#
# [5 rows x 12 columns]

# %%
df['sex']=df['sex'].map({'male':0,'female':1})
df['sex'].value_counts()
# Out:
# 0    843
# 1    466
# Name: sex, dtype: int64

# %%
df['ticket']=encoder.fit_transform(df['ticket'])
df.head()
# Out:
#    pclass  survived  name  sex  ...      fare  embarked    title  familysize
# 0       1       1.0    21    1  ...  211.3375         S     Miss           0
# 1       1       1.0    23    0  ...  151.5500         S   Master           3
# 2       1       0.0    24    1  ...  151.5500         S     Miss           3
# 3       1       0.0    25    0  ...  151.5500         S       Mr           3
# 4       1       0.0    26    1  ...  151.5500         S      Mrs           3
#
# [5 rows x 12 columns]

# %%
df['embarked'].value_counts()
# Out:
# S    916
# C    270
# Q    123
# Name: embarked, dtype: int64

# %%
df['embarked']=df['embarked'].map({'S':1,'C':2,'Q':3})
df['embarked'].value_counts()
# Out:
# 1    916
# 2    270
# 3    123
# Name: embarked, dtype: int64

# %%
df['title'].value_counts()
# Out:
#  Mr              757
#  Miss            260
#  Mrs             197
#  Master           61
#  Dr                8
#  Rev               8
#  Col               4
#  Major             2
#  Ms                2
#  Mlle              2
#  Mme               1
#  Jonkheer          1
#  Dona              1
#  Lady              1
#  Don               1
#  Sir               1
#  Capt              1
#  the Countess      1
# Name: title, dtype: int64

# %%
df['title']=encoder.fit_transform(df['title'])
df.head()
# Out:
#    pclass  survived  name  sex  ...      fare  embarked  title  familysize
# 0       1       1.0    21    1  ...  211.3375         1      9           0
# 1       1       1.0    23    0  ...  151.5500         1      8           3
# 2       1       0.0    24    1  ...  151.5500         1      9           3
# 3       1       0.0    25    0  ...  151.5500         1     12           3
# 4       1       0.0    26    1  ...  151.5500         1     13           3
#
# [5 rows x 12 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1309 entries, 0 to 1308
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   pclass      1309 non-null   int64
#  1   survived    1309 non-null   float64
#  2   name        1309 non-null   int64
#  3   sex         1309 non-null   int64
#  4   age         1309 non-null   int64
#  5   sibsp       1309 non-null   int64
#  6   parch       1309 non-null   int64
#  7   ticket      1309 non-null   int64
#  8   fare        1309 non-null   float64
#  9   embarked    1309 non-null   int64
#  10  title       1309 non-null   int64
#  11  familysize  1309 non-null   int64
# dtypes: float64(2), int64(10)
# memory usage: 132.9 KB

# %%
#features extraction
x=df[['sex','age','sibsp','pclass']]
y=df['survived']

x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.20,random_state=42) #splitting data with test size of 20%

model = LogisticRegression()   #build our logistic model
model.fit(x_train, y_train)  #fitting training data
y_pred  = model.predict(x_test)    #testing model’s performance

print("Accuracy={:.2f}".format(model.score(x_test, y_test)))
# Out:
# Accuracy=0.77

# %%
sns.regplot(x='age',y='survived',data=df,logistic=True)

# %%
sns.regplot(x='sex',y='survived',data=df,logistic=True)

# %%
confusion_matrix = pd.crosstab(y_test, y_pred, rownames=['Actual'], colnames=['Predicted'])
print(confusion_matrix)
# Out:
# Predicted  0.0  1.0
# Actual
# 0.0        127   17
# 1.0         44   74

# %% [markdown]
# ### Conclusion
# True positive : 127 // True negative : 74 // False positive : 17 // False negative : 44

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.74      0.88      0.81       144
#          1.0       0.81      0.63      0.71       118
#
#     accuracy                           0.77       262
#    macro avg       0.78      0.75      0.76       262
# weighted avg       0.77      0.77      0.76       262

# %% [markdown]
# ## ROC & AUC

# %%
#generate two class dataset
x, y = make_classification(n_samples=1000, n_classes=2, n_features=20, random_state=42)

#splitting data with test size of 20%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.20,random_state=42)

# %%
log_model = LogisticRegression() #logistic regression model
knn_model = KNeighborsClassifier(n_neighbors=4) #knn model

#fit model
log_model.fit(x_train, y_train)
knn_model.fit(x_train, y_train)

#predict probabilities

pred_prob_log = log_model.predict_proba(x_test)
pred_prob_knn = knn_model.predict_proba(x_test)

# %%
# roc curve for models
fpr1, tpr1, thresh1 = roc_curve(y_test, pred_prob_log[:,1], pos_label=1)
fpr2, tpr2, thresh2 = roc_curve(y_test, pred_prob_knn[:,1], pos_label=1)

#roc curve for tpr = fpr
random_probs = [0 for i in range(len(y_test))]
p_fpr, p_tpr, _ = roc_curve(y_test, random_probs, pos_label=1)

# %%
# auc scores

auc_score_log = roc_auc_score(y_test, pred_prob_log[:,1])
auc_score_knn = roc_auc_score(y_test, pred_prob_knn[:,1])

print('Logistic AUC score :',auc_score_log)
print('KNN AUC score :',auc_score_knn)
# Out:
# Logistic AUC score : 0.9216159179981912
# KNN AUC score : 0.8737312832881117

# %%
plt.style.use('seaborn')

# plot roc curves
plt.plot(fpr1, tpr1, linestyle='--',color='red', label='Logistic Regression')
plt.plot(fpr2, tpr2, linestyle='--',color='blue', label='KNN')
plt.plot(p_fpr, p_tpr, linestyle='--',color='green')
#title
plt.title('Roc curve')
# x label
plt.xlabel('False Positive Rate (FPR)')
# y label
plt.ylabel('True Positive Rate (TPR)')

plt.legend(loc='best')
plt.savefig('ROC', dpi=300)
plt.show()

# %% [markdown]
# The green line in the middle represents a purely random classifier and therefore our classifier should be as far away from it as possible. Our logistic regression model seems to do a good job.

# %% [markdown]
# # Decision Tree

# %%
#features extraction
x=df[['sex','age','pclass','embarked','sibsp']]
y= df['survived']

#splitting data
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.20,random_state=10)

#applying tree algorithm

d_model = tree.DecisionTreeClassifier()
d_model.fit(x_train, y_train)   #fitting our model
y_pred=d_model.predict(x_test)   # evaluating our model
print("score:{}".format(accuracy_score(y_test, y_pred)))
# Out:
# score:0.7862595419847328

# %%
dot_data = tree.export_graphviz(d_model, out_file=None)
graph = graphviz.Source(dot_data)
graph.render('data')
graph

# %%
f_model = RandomForestClassifier(n_estimators =1000)
f_model.fit(x_train, y_train)
y_pred = f_model.predict(x_test)
print ("Accuracy:" , metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.8015267175572519

# %%
f_model = RandomForestClassifier(n_estimators =10)
f_model.fit(x_train, y_train)
y_pred = f_model.predict(x_test)
print ("Accuracy:" , metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.8053435114503816
